# %% [markdown]
# ## 1. Случайная непрерывная величина A имеет равномерное распределение на промежутке (200, 800]. Найдите ее среднее значение и дисперсию.

# %% [markdown]
# $$M(X)=\frac{a+b}{2}$$
#
# $$D(X)=\frac{(b-a)^2}{12}$$

# %%
a,b = 200,800

m = (a+b) / 2

d = (b-a)**2 / 12

print(f'Среднее значение: {m}')
print(f'Дисперсия: {d}')
# Out:
# Среднее значение: 500.0
# Дисперсия: 30000.0

# %% [markdown]
# ## 2. О случайной непрерывной равномерно распределенной величине B известно, что ее дисперсия равна 0.2. Можно ли найти правую границу величины B и ее среднее значение зная, что левая граница равна 0.5? Если да, найдите ее.

# %% [markdown]
# $D(X)=0.2$
#
# $a = 0.5$
#
# $$b = \sqrt{D(X)\cdot12} + a$$

# %%
a = 0.5
d = 0.2

b = (d*12)**0.5 + a
m = (a + b) / 2

print(f'Правая граница: {b:.2f}')
print(f'Среднее значение: {m:.2f}')
# Out:
# Правая граница: 2.05
# Среднее значение: 1.27

# %% [markdown]
# ## 3. Непрерывная случайная величина X распределена нормально и задана плотностью распределения $f(x) = \frac{1}{4 \cdot \sqrt{2\pi}} \cdot e^{-\frac{(x+2)^2}{32}}$
#
# **Найдите:**
#
# **а). M(X)**
#
# **б). D(X)**
#
# **в). std(X) (среднее квадратичное отклонение)**

# %% [markdown]
# ## $$f(x) = \frac{1}{\sigma \cdot \sqrt{2\pi}} \cdot e^{-\frac{(x-a)^2}{32}}$$

# %% [markdown]
# ## $$\frac{1}{4 \cdot \sqrt{2\pi}} \cdot e^{-\frac{(x+2)^2}{32}} = \frac{1}{\sigma \cdot \sqrt{2\pi}} \cdot e^{-\frac{(x-a)^2}{32}}$$
#
# Соответственно:
#
# $M(X)=-2$
#
# $D(X)=16$
#
# $std(X)=4$

# %% [markdown]
# ## 4. Рост взрослого населения города X имеет нормальное распределение. Причем, средний рост равен 174 см, а среднее квадратичное отклонение равно 8 см. Какова вероятность того, что случайным образом выбранный взрослый человек имеет рост:
# ### а). больше 182 см
#
# $z=\frac{182-174}{8}=1$
#
# По таблице получаем 0.8413
#
# $p=1-0.8413=0.1587$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост больше 182 см равна 0.1587(~16%).
#
# ### б). больше 190 см
#
# $z=\frac{190-174}{8}=2$
#
# По таблице получаем 0.9772
#
# $p=1-0.9772=0.0228$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост больше 190 см равна 0.0228(~2%).
#
# ### в). от 166 см до 190 см
#
# $z1=\frac{190-174}{8}=2$
#
# $z2=\frac{166-174}{8}=-1$
#
# По таблице получаем 0.9772 для z1 и 0.1587 для z2.
#
# $p=0.9772-0.1587=0.8185$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост от 166 до 190 см равна 0.8185(~82%).
#
# ### г). от 166 см до 182 см
#
# $z1=\frac{182-174}{8}=1$
#
# $z2=\frac{166-174}{8}=-1$
#
# По таблице получаем 0.8413 для z1 и 0.1587 для z2.
#
# $p=0.8413-0.1587=0.6826$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост от 166 до 182 см равна 0.6826(~68%).
#
# ### д). от 158 см до 190 см
#
# $z1=\frac{190-174}{8}=2$
#
# $z2=\frac{158-174}{8}=-2$
#
# По таблице получаем 0.9772 для z1 и 0.0228 для z2.
#
# $p=0.9772-0.0228=0.9544$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост от 158 до 190 см равна 0.9544(~95%).
#
# ### е). не выше 150 см или не ниже 190 см
#
# $z1=\frac{190-174}{8}=2$
#
# $z2=\frac{150-174}{8}=-3$
#
# По таблице получаем 0.9772 для z1 и 0.0014 для z2.
#
# $p=(1-0.9772)+0.0014=0.0242$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост не выше 150 или не ниже 190 см равна 0.0242(~2.4%).
#
# ### ё). не выше 150 см или не ниже 198 см
#
# $z1=\frac{198-174}{8}=3$
#
# $z2=\frac{150-174}{8}=-3$
#
# По таблице получаем 0.9986 для z1 и 0.0014 для z2.
#
# $p=(1-0.9986)+0.0014=0.0028$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост не выше 150 или не ниже 198 см равна 0.0028(~0.3%).
#
# ### ж). ниже 166 см
#
# $z=\frac{166-174}{8}=-1$
#
# По таблице получаем 0.1587
#
# $p=0.1587$
#
# ### Ответ: Вероятность, что случайным образом выбранный взрослый человек имеет рост ниже 166 см равна 0.1587(~16%).

# %% [markdown]
# ## 5.На сколько сигм (средних квадратичных отклонений) отклоняется рост человека, равный 190 см, от математического ожидания роста в популяции, в которой M(X) = 178 см и D(X) = 25 кв.см?

# %% [markdown]
# $z=\frac{190-178}{5}=2.4$
#
# ### Ответ: рост человека, равный 190 см, отклоняется на 2.4 сигмы.
