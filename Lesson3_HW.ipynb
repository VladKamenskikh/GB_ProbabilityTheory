# %%
import numpy as np
from math import factorial

def combinations(n,k):
    return int(factorial(n) / (factorial(k) * factorial(n-k)))

# %% [markdown]
# ## 1. Даны значения зарплат из выборки выпускников: 100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150. Посчитать (желательно без использования статистических методов наподобие std, var, mean) среднее арифметическое, среднее квадратичное отклонение, смещенную и несмещенную оценки дисперсий для данной выборки.

# %%
salaries = np.array([100, 80, 75, 77, 89, 33, 45, 25, 65, 17, 30, 24, 57, 55, 70, 75, 65, 84, 90, 150])

mean = salaries.sum() / len(salaries)
print(f'Среднее арифметическое: {mean}')

sum_salaries = 0
for salary in salaries:
    sum_salaries += (salary - mean)**2

std = np.sqrt(sum_salaries / len(salaries))
print(f'Среднее квадратичное отклонение: {std:.2f}')

var1 = sum_salaries / len(salaries)
print(f'Смещенная оценка дисперсии: {var1}')

var2 = sum_salaries / (len(salaries)-1)
print(f'Несмещенная оценка дисперсии: {var2:.2f}')
# Out:
# Среднее арифметическое: 65.3
# Среднее квадратичное отклонение: 30.82
# Смещенная оценка дисперсии: 950.11
# Несмещенная оценка дисперсии: 1000.12

# %% [markdown]
# ## 2. В первом ящике находится 8 мячей, из которых 5 - белые. Во втором ящике - 12 мячей, из которых 5 белых. Из первого ящика вытаскивают случайным образом два мяча, из второго - 4. Какова вероятность того, что 3 мяча белые?

# %% [markdown]
# $$p1 = \frac{C_5^2 C_3^0}{C_8^2}\cdot \frac{C_5^1 C_7^3}{C_{12}^4}$$
#
# $$p2 = \frac{C_5^1 C_3^1}{C_8^2}\cdot \frac{C_5^2 C_7^2}{C_{12}^4}$$
#
# $$p3 = \frac{C_5^0 C_3^2}{C_8^2}\cdot \frac{C_5^3 C_7^1}{C_{12}^4}$$
#
# $$p=p1+p2+p3$$

# %%
p1 = ((combinations(5,2)*combinations(3,0))/combinations(8,2))*((combinations(5,1)*combinations(7,3))/combinations(12,4))
p2 = ((combinations(5,1)*combinations(3,1))/combinations(8,2))*((combinations(5,2)*combinations(7,2))/combinations(12,4))
p3 = ((combinations(5,0)*combinations(3,2))/combinations(8,2))*((combinations(5,3)*combinations(7,1))/combinations(12,4))

p = p1 + p2 + p3
print(f'Вероятность, что 3 мяча белые: {p:.3f}')
# Out:
# Вероятность, что 3 мяча белые: 0.369

# %% [markdown]
# ## 3. На соревновании по биатлону один из трех спортсменов стреляет и попадает в мишень. Вероятность попадания для первого спортсмена равна 0.9, для второго — 0.8, для третьего — 0.6. Найти вероятность того, что выстрел произведен: a). первым спортсменом б). вторым спортсменом в). третьим спортсменом.

# %% [markdown]
# $$P(B\:|\:A) = \frac{P(B) \cdot P(A\:|\:B)}{P(A)}$$

# %%
p1, p2, p3 = 0.9, 0.8, 0.6

pA = 1/3*p1 + 1/3*p2 + 1/3*p3

print(f'Вероятность того, что выстрел произведен первым спортсменом: {1/3*p1/pA:.3f}')
print(f'Вероятность того, что выстрел произведен вторым спортсменом: {1/3*p2/pA:.3f}')
print(f'Вероятность того, что выстрел произведен третьим спортсменом: {1/3*p3/pA:.3f}')
# Out:
# Вероятность того, что выстрел произведен первым спортсменом: 0.391
# Вероятность того, что выстрел произведен вторым спортсменом: 0.348
# Вероятность того, что выстрел произведен третьим спортсменом: 0.261

# %% [markdown]
# ## 4. В университет на факультеты A и B поступило равное количество студентов, а на факультет C студентов поступило столько же, сколько на A и B вместе. Вероятность того, что студент факультета A сдаст первую сессию, равна 0.8. Для студента факультета B эта вероятность равна 0.7, а для студента факультета C - 0.9. Студент сдал первую сессию. Какова вероятность, что он учится: a). на факультете A б). на факультете B в). на факультете C?

# %% [markdown]
# $$P(B\:|\:A) = \frac{P(B) \cdot P(A\:|\:B)}{P(A)}$$

# %%
p1, p2, p3 = 0.8, 0.7, 0.9

pA = 1/4*p1 + 1/4*p2 + 1/2*p3

print(f'Вероятность, что студент учится на факультете А: {1/4*p1/pA:.3f}')
print(f'Вероятность, что студент учится на факультете B: {1/4*p2/pA:.3f}')
print(f'Вероятность, что студент учится на факультете C: {1/2*p3/pA:.3f}')
# Out:
# Вероятность, что студент учится на факультете А: 0.242
# Вероятность, что студент учится на факультете А: 0.212
# Вероятность, что студент учится на факультете А: 0.545

# %% [markdown]
# ## 5. Устройство состоит из трех деталей. Для первой детали вероятность выйти из строя в первый месяц равна 0.1, для второй - 0.2, для третьей - 0.25. Какова вероятность того, что в первый месяц выйдут из строя: а). все детали б). только две детали в). хотя бы одна деталь г). от одной до двух деталей?

# %%
p1, p2, p3 = 0.1, 0.2, 0.25

print(f'Вероятность, что в первый месяц из строя выйдут все детали: {p1*p2*p3:.3f}')
print(f'Вероятность, что в первый месяц из строя выйдут только две детали: {(1-p1)*p2*p3+(1-p2)*p1*p3+(1-p3)*p1*p2:.3f}')
print(f'Вероятность, что в первый месяц из строя выйдет хотя бы одна деталь: {1-((1-p1)*(1-p2)*(1-p3)):.3f}')
print(f'Вероятность, что в первый месяц из строя выйдут от одной до двух деталей: {1-((1-p1)*(1-p2)*(1-p3))-p1*p2*p3:.3f}')
# Out:
# Вероятность, что в первый месяц из строя выйдут все детали: 0.005
# Вероятность, что в первый месяц из строя выйдут только две детали: 0.080
# Вероятность, что в первый месяц из строя выйдет хотя бы одна деталь: 0.460
# Вероятность, что в первый месяц из строя выйдут от одной до двух деталей: 0.455
